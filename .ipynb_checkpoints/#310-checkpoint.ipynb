# %% [markdown]
# This is based off an old notebook by Ben Pope. If we can recreate what he did using lightkurve alone, it will be a success!

# %%
import numpy as np
import matplotlib.pyplot as plt

from astropy.table import Table, join, Column
from astropy.stats import LombScargle
import astropy.units as u                          # We'll need this later.

from astropy.io import ascii
import glob, re

import lightkurve

import matplotlib as mpl
mpl.style.use('seaborn-colorblind')

#To make sure we have always the same matplotlib settings

#(the ones in comments are the ipython notebook settings)
mpl.rcParams['text.usetex'] = False
mpl.rcParams['figure.figsize']=(12.0,9.0)    #(6.0,4.0)
mpl.rcParams['font.size']=20               #10 
mpl.rcParams['savefig.dpi']= 200             #72 
mpl.rcParams['axes.labelsize'] = 18
mpl.rcParams['axes.labelsize'] = 18
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
from matplotlib import rc

colours = mpl.rcParams['axes.prop_cycle'].by_key()['color']

# %%
lcs = lightkurve.search_lightcurvefile(8197761,cadence='long').download_all()
for j, lci in enumerate(lcs):
    lci = lci.get_lightcurve('PDCSAP_FLUX').remove_nans()
    lci = lci[lci.quality==0]
    lcs[j] = lci.normalize()

lcr = lcs[0]
for lci in lcs[1:]:
    lcr = lcr.append(lci)

# %%
pg = lcr.to_periodogram(min_period = 8./24.*u.day, max_period=20.*u.day)
pg.plot()
# Out:
# /home/oliver/.local/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
pg._LS_object

# %%
y_fit = pg.get_lombscargle_model(lcr) #Now lightkurve functionality
# Out:
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/astropy/stats/lombscargle/core.py in _validate_frequency(self, frequency)
#     135             try:
# --> 136                 frequency = units.Quantity(frequency, unit=1./self.t.unit)
#     137             except units.UnitConversionError:
#
# ~/.local/lib/python3.6/site-packages/astropy/units/quantity.py in __new__(cls, value, unit, dtype, copy, order, subok, ndmin)
#     286             if unit is not None and unit is not value.unit:
# --> 287                 value = value.to(unit)
#     288                 # the above already makes a copy (with float dtype)
#
# ~/.local/lib/python3.6/site-packages/astropy/units/quantity.py in to(self, unit, equivalencies)
#     670         unit = Unit(unit)
# --> 671         return self._new_view(self._to_value(unit, equivalencies), unit)
#     672
#
# ~/.local/lib/python3.6/site-packages/astropy/units/quantity.py in _to_value(self, unit, equivalencies)
#     642         return self.unit.to(unit, self.view(np.ndarray),
# --> 643                             equivalencies=equivalencies)
#     644
#
# ~/.local/lib/python3.6/site-packages/astropy/units/core.py in to(self, other, value, equivalencies)
#     988         else:
# --> 989             return self._get_converter(other, equivalencies=equivalencies)(value)
#     990
#
# ~/.local/lib/python3.6/site-packages/astropy/units/core.py in _get_converter(self, other, equivalencies)
#     919
# --> 920             raise exc
#     921
#
# ~/.local/lib/python3.6/site-packages/astropy/units/core.py in _get_converter(self, other, equivalencies)
#     905             return self._apply_equivalencies(
# --> 906                 self, other, self._normalize_equivalencies(equivalencies))
#     907         except UnitsError as exc:
#
# ~/.local/lib/python3.6/site-packages/astropy/units/core.py in _apply_equivalencies(self, unit, other, equivalencies)
#     889             "{0} and {1} are not convertible".format(
# --> 890                 unit_str, other_str))
#     891
#
# UnitConversionError: '' (dimensionless) and '1 / d' (frequency) are not convertible
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-540c312263d8> in <module>
# ----> 1 y_fit = pg.get_lombscargle_model(lcr) #Now lightkurve functionality
#
# ~/.local/lib/python3.6/site-packages/lightkurve-1.0b30.dev0-py3.6.egg/lightkurve/periodogram.py in get_lombscargle_model(self, lc, frequency, period)
#     767
#     768         #Caculate the model
# --> 769         y_fit = self._LS_object.model(time, frequency.value)
#     770         return y_fit
#     771
#
# ~/.local/lib/python3.6/site-packages/astropy/stats/lombscargle/core.py in model(self, t, frequency)
#     356             The model fit corresponding to the input times
#     357         """
# --> 358         frequency = self._validate_frequency(frequency)
#     359         t = self._validate_t(t)
#     360         y_fit = periodic_fit(*strip_units(self.t, self.y, self.dy),
#
# ~/.local/lib/python3.6/site-packages/astropy/stats/lombscargle/core.py in _validate_frequency(self, frequency)
#     136                 frequency = units.Quantity(frequency, unit=1./self.t.unit)
#     137             except units.UnitConversionError:
# --> 138                 raise ValueError("Units of frequency not equivalent to "
#     139                                  "units of 1/t")
#     140         else:
#
# ValueError: Units of frequency not equivalent to units of 1/t

# %%
ax = lcr.plot()
ax.plot(lcr.time,lcr.flux-y_fit+1,'.', label='With fitted model removed')
ax.legend()
ax.set_xlim(lcr.time.min(),lcr.time.min()+50)

# %% [markdown]
# Lets iteratively fit sines to remove noise

# %%
ff, pp = [], []
lc = lcr.copy()
for j in range(60):
    pg = lc.to_periodogram(min_period=4./24.*u.day, max_period=30.*u.day)
    ff.append(pg.frequency_at_max_power.value)
    pp.append(pg.max_power.value)
    y_fit = pg.model(lc)   #Now lightkurve functionality
#     y_fit = LombScargle(lc.time, lc.flux, lc.flux_err).model(lc.time, pg.frequency_at_max_power.value)
    lc.flux = lc.flux- y_fit + 1.
ax = lcr.plot(label='original')
lc.plot(ax=ax, label='reduced')
ax.legend()
plt.show()

# %% [markdown]
# Check the flattening worked

# %%
ax = lcr.plot(alpha=.2)
lc.plot(ax=ax)
lc.flatten().plot(ax=ax)
plt.xlim(500,900)
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %% [markdown]
# Fold the planet on the period, and bin

# %%
planet_period = 9.8686667
folded = lc.fold(planet_period, transit_midpoint = planet_period)
binned = folded.bin(binsize=25,method='median')

# %%
ax = lcr.fold(planet_period, transit_midpoint = planet_period).plot(alpha=.1, label='original')
folded.plot(alpha=.2, ax=ax, label='reduced')
binned.plot(ax=ax, label='binned')
ax.legend()
plt.xlabel('Phase')
plt.ylabel('Normalized Flux')
plt.title('KIC %d: Period %.3f d' % (lc.targetid,planet_period))
# Out:
# Text(0.5, 1.0, 'KIC 8197761: Period 9.869 d')

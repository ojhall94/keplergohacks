# %%
import lightkurve as lk

# %%
lc1 = lk.search_lightcurvefile('GJ 9827', campaign=12).download()
lc1.plot()

# %%
lc2 = lk.search_lightcurvefile('GJ 9827', mission='Kepler', provenance_name='K2', campaign=12).download()
# Out:
# No data found for target "GJ 9827".
# /usr/local/lib/python3.7/site-packages/lightkurve-1.11.dev0-py3.7.egg/lightkurve/search.py:226: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)

# %%
lc2 = lk.search_lightcurvefile('GJ 9827', mission='K2', provenance_name='Kepler', campaign=12).download()
# Out:
# No data found for target "GJ 9827".
# /usr/local/lib/python3.7/site-packages/lightkurve-1.11.dev0-py3.7.egg/lightkurve/search.py:226: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)

# %%
lc2 = lk.search_lightcurvefile('GJ 9827', mission='K2', provenance_name='EVEREST', campaign=12).download()

# %%
lc2.plot()

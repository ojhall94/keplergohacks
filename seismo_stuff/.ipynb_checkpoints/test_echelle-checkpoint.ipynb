# %% [markdown]
# # Test echelle on MS star

# %%
import lightkurve as lk
import warnings
warnings.filterwarnings('ignore')

# %%
datalist = lk.search_lightcurvefile('16CygA',cadence='short')
data = datalist[3:4].download_all()
lc = data[0].PDCSAP_FLUX.normalize().flatten()
for nlc in data:
    lc = lc.append(nlc.PDCSAP_FLUX.normalize().flatten())
lc = lc.remove_nans()
pg = lc.to_periodogram(normalization='psd')
snr = pg.flatten()

# %%
numax, ax = snr.estimate_numax(show_plots=True)
print('Our value for numax is: {:.2f}'.format(numax))
dnu, ax = snr.estimate_dnu(show_plots=True)
print('Our value for dnu is: {:.2f}'.format(dnu))
# Out:
# Our value for numax is: 2190.08 uHz
# Our value for dnu is: 103.41 uHz

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = snr.frequency.value
p = snr.power.value
d = dnu.value
nmx = numax.value
fwhm = 0.25*numax.value
fs = np.median(np.diff(f))

# %% [markdown]
# ## My way (adapted from Dan Hey)

# %%
fmin = nmx - 2*fwhm   #The lower frequency bound
fmax = nmx + 2*fwhm   #The upper frequency bound

fmax += d #Add one 1x Dnu so we don't miss off any important range due to rounding cutt offs

fs = np.median(np.diff(f)) #The frequency spacing

ff = f[int(fmin/fs):int(fmax/fs)] #The the selected frequency range
pp = p[int(fmin/fs):int(fmax/fs)] #The selected power range

n_stack = int((ff[-1]-ff[0])/d)         #The number of stacks to use
n_element = int(d/fs)  #The number of elements in each stack

# %%
ep = np.reshape(pp[:(n_stack*n_element)],(n_stack,n_element)) #Reshape the power into n_stacks of n_elements
ef = np.reshape(ff[:(n_stack*n_element)],(n_stack,n_element)) #Reshape the freq into n_stacks of n_elements

# %%
x_f = (ef[0,:]-ef[0,0]) % d
y_f = (ef[:,0])
X, Y = np.meshgrid(x_f, y_f)

# %% [markdown]
# I need to figure out how to do axis labels properly with imshow

# %%
with plt.style.context(lk.MPLSTYLE):
    fig, ax = plt.subplots()

    
    figsize = plt.rcParams['figure.figsize']
    a = figsize[1]/figsize[0]
    b = len(y_f)/len(x_f)
    
    ax.imshow(ep,cmap='Blues',aspect=a/b, origin='lower')
    
    xticks = ax.get_xticks()
    dx = np.median(np.diff(x_f))
    ax.set_xticklabels(np.round(xticks * dx + x_f[0],2))
    yticks = ax.get_yticks()
    dy = np.median(np.diff(y_f))
    ax.set_yticklabels(np.round(yticks * dy + y_f[0],0))                      

    
    ax.set_xlabel(r'Frequency mod. {:.2f} {}'.format(dnu.value, dnu.unit.to_string('latex')))
    ax.set_ylabel(r'Frequency [{}]'.format(dnu.unit.to_string('latex')))

# %%
x_f
# Out:
# array([  0.        ,   0.38429448,   0.76858896,   1.15288344,
#          1.53717792,   1.9214724 ,   2.30576688,   2.69006136,
#          3.07435584,   3.45865032,   3.8429448 ,   4.22723928,
#          4.61153376,   4.99582824,   5.38012272,   5.7644172 ,
#          6.14871168,   6.53300616,   6.91730064,   7.30159512,
#          7.6858896 ,   8.07018408,   8.45447856,   8.83877304,
#          9.22306752,   9.607362  ,   9.99165648,  10.37595096,
#         10.76024544,  11.14453992,  11.5288344 ,  11.91312888,
#         12.29742336,  12.68171784,  13.06601232,  13.4503068 ,
#         13.83460128,  14.21889576,  14.60319024,  14.98748472,
#         15.3717792 ,  15.75607369,  16.14036817,  16.52466265,
#         16.90895713,  17.29325161,  17.67754609,  18.06184057,
#         18.44613505,  18.83042953,  19.21472401,  19.59901849,
#         19.98331297,  20.36760745,  20.75190193,  21.13619641,
#         21.52049089,  21.90478537,  22.28907985,  22.67337433,
#         23.05766881,  23.44196329,  23.82625777,  24.21055225,
#         24.59484673,  24.97914121,  25.36343569,  25.74773017,
#         26.13202465,  26.51631913,  26.90061361,  27.28490809,
#         27.66920257,  28.05349705,  28.43779153,  28.82208601,
#         29.20638049,  29.59067497,  29.97496945,  30.35926393,
#         30.74355841,  31.12785289,  31.51214737,  31.89644185,
#         32.28073633,  32.66503081,  33.04932529,  33.43361977,
#         33.81791425,  34.20220873,  34.58650321,  34.97079769,
#         35.35509217,  35.73938665,  36.12368113,  36.50797561,
#         36.89227009,  37.27656457,  37.66085905,  38.04515353,
#         38.42944801,  38.81374249,  39.19803697,  39.58233145,
#         39.96662593,  40.35092041,  40.73521489,  41.11950937,
#         41.50380385,  41.88809833,  42.27239281,  42.65668729,
#         43.04098177,  43.42527625,  43.80957073,  44.19386521,
#         44.57815969,  44.96245417,  45.34674865,  45.73104313,
#         46.11533761,  46.49963209,  46.88392657,  47.26822106,
#         47.65251554,  48.03681002,  48.4211045 ,  48.80539898,
#         49.18969346,  49.57398794,  49.95828242,  50.3425769 ,
#         50.72687138,  51.11116586,  51.49546034,  51.87975482,
#         52.2640493 ,  52.64834378,  53.03263826,  53.41693274,
#         53.80122722,  54.1855217 ,  54.56981618,  54.95411066,
#         55.33840514,  55.72269962,  56.1069941 ,  56.49128858,
#         56.87558306,  57.25987754,  57.64417202,  58.0284665 ,
#         58.41276098,  58.79705546,  59.18134994,  59.56564442,
#         59.9499389 ,  60.33423338,  60.71852786,  61.10282234,
#         61.48711682,  61.8714113 ,  62.25570578,  62.64000026,
#         63.02429474,  63.40858922,  63.7928837 ,  64.17717818,
#         64.56147266,  64.94576714,  65.33006162,  65.7143561 ,
#         66.09865058,  66.48294506,  66.86723954,  67.25153402,
#         67.6358285 ,  68.02012298,  68.40441746,  68.78871194,
#         69.17300642,  69.5573009 ,  69.94159538,  70.32588986,
#         70.71018434,  71.09447882,  71.4787733 ,  71.86306778,
#         72.24736226,  72.63165674,  73.01595122,  73.4002457 ,
#         73.78454018,  74.16883466,  74.55312914,  74.93742362,
#         75.3217181 ,  75.70601258,  76.09030706,  76.47460154,
#         76.85889602,  77.2431905 ,  77.62748498,  78.01177946,
#         78.39607394,  78.78036843,  79.16466291,  79.54895739,
#         79.93325187,  80.31754635,  80.70184083,  81.08613531,
#         81.47042979,  81.85472427,  82.23901875,  82.62331323,
#         83.00760771,  83.39190219,  83.77619667,  84.16049115,
#         84.54478563,  84.92908011,  85.31337459,  85.69766907,
#         86.08196355,  86.46625803,  86.85055251,  87.23484699,
#         87.61914147,  88.00343595,  88.38773043,  88.77202491,
#         89.15631939,  89.54061387,  89.92490835,  90.30920283,
#         90.69349731,  91.07779179,  91.46208627,  91.84638075,
#         92.23067523,  92.61496971,  92.99926419,  93.38355867,
#         93.76785315,  94.15214763,  94.53644211,  94.92073659,
#         95.30503107,  95.68932555,  96.07362003,  96.45791451,
#         96.84220899,  97.22650347,  97.61079795,  97.99509243,
#         98.37938691,  98.76368139,  99.14797587,  99.53227035,
#         99.91656483, 100.30085931, 100.68515379, 101.06944827,
#        101.45374275, 101.83803723, 102.22233171, 102.60662619,
#        102.99092067])

# %% [markdown]
# ## Dan Hey's way

# %%
fmin = nmx - 2*fwhm
fmax = nmx + 2*fwhm


samplinginterval = np.median(np.diff(f))

xp = np.arange(fmin,fmax+d,samplinginterval)
yp = np.interp(xp, f, p) #This shouldn't be interpolation, this should be a slice...

n_stack = int((fmax-fmin)/d)
n_element = int(d/samplinginterval)

# %%
morerow = 2
arr = np.arange(1,n_stack) * d #This accounts for the rounding error I think?
arr2 = np.array([arr,arr])
yn = np.reshape(arr2,len(arr)*2,order="F")
yn = np.insert(yn,0,0.0)  #Add on a zero
yn = np.append(yn,n_stack*d) + fmin #Add on the top?

# %%
xn = np.linspace(1, n_element, n_element) * d
z = np.zeros([n_stack*morerow,n_element])

# %%
#This stacks the power values
for i in range(n_stack):
    for j in range(i*morerow,(i+1)*morerow):
        z[j,:] = yp[n_element*(i):n_element*(i+1)]

# %%
with plt.style.context(lk.MPLSTYLE):
    fig, ax = plt.subplots()
    # nlevels=32
    # levels = np.linspace(np.min(z),np.max(xn),nlevels)
    # Using levels is very slow for some reason.. 

    ax.contourf(xn,yn,z,cmap='gray_r')
    # ax.axis([np.min(xn),np.max(xn),np.min(yn),np.max(yn)])

    ax.set_xlabel(r'Frequency' +' mod ' + str(dnu))
    ax.set_ylabel(r'Frequency')

# %%
z.shape
# Out:
# (42, 269)

# %%
ep.shape
# Out:
# (22, 269)

# %% [markdown]
# ## Old code

# %%
morerow = 2
arr = np.arange(1,n_stack) * d #This accounts for the rounding error I think?
arr2 = np.array([arr,arr])
yn = np.reshape(arr2,len(arr)*2,order="F")
yn = np.insert(yn,0,0.0)  #Add on a zero
yn = np.append(yn,n_stack*d) + fmin #Add on the top?

# %% [markdown]
# # Lets try it Guys way

# %%
import numpy as np
import pylab as plt

f = snr.frequency.value
p = snr.power.value
d = dnu.value
nmx = numax.value
fwhm = 0.25*numax.value
fs = np.median(np.diff(f))

# %%
w = int(d/fs)
s = 4000
h = int(np.floor(len(p[s:7500]))/w)

# %%
lp = np.reshape(p[s:h*w+1], [h,w])
lf = np.reshape(f[s:h*w+1], [h,w])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-016412ad44f5> in <module>
# ----> 1 lp = np.reshape(p[s:h*w+1], [h,w])
#       2 lf = np.reshape(f[s:h*w+1], [h,w])
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     290            [5, 6]])
#     291     """
# --> 292     return _wrapfunc(a, 'reshape', newshape, order=order)
#     293
#     294
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      54 def _wrapfunc(obj, method, *args, **kwds):
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#      58     # An AttributeError occurs if the object does not have
#
# ValueError: cannot reshape array of size 0 into shape (13,269)

# %%
plt.plot(p[s:h*w])

# %%
plt.contourf(lp, ladder=100)

# %%
nn = 14
d_f = lf[0,:] / d
fig, ax = plt.subplots(nn,figsize=(12,8),sharey=True)
for i in range(int(nn)):
        ax[i].plot(d_f, lp[i,:], label=f'Index: {i}')
        ax[i].set_yticks([])
        if i != nn-1:
            ax[i].set_xticks([])
plt.subplots_adjust(hspace=0.0, wspace=0.0)
